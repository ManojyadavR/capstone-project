# %%
import pandas as pd
url = "employee_attrition_data.csv"
df = pd.read_csv(url)

# %%
print(df)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0              0   27    Male    Marketing        Manager                 9
# 1              1   53  Female        Sales       Engineer                10
# 2              2   59  Female    Marketing        Analyst                 8
# 3              3   42  Female  Engineering        Manager                 1
# 4              4   44  Female        Sales       Engineer                10
# ..           ...  ...     ...          ...            ...               ...
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0              0.586251                    151                      0   60132
# 1              0.261161                    221                      1   79947
# 2              0.304382                    184                      0   46958
# 3              0.480779                    242                      0   40662
# 4              0.636244                    229                      1   74307
# ..                  ...                    ...                    ...     ...
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0
# ..         ...
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1
#
# [1000 rows x 11 columns]

# %%
df.head(10)
# Out:
#    Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing        Manager                 9
# 1            1   53  Female        Sales       Engineer                10
# 2            2   59  Female    Marketing        Analyst                 8
# 3            3   42  Female  Engineering        Manager                 1
# 4            4   44  Female        Sales       Engineer                10
# 5            5   47    Male        Sales  HR Specialist                10
# 6            6   58    Male    Marketing  HR Specialist                 5
# 7            7   57  Female        Sales        Analyst                 8
# 8            8   34  Female      Finance     Accountant                 6
# 9            9   57  Female    Marketing       Engineer                 7
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
# 5            0.889018                    237                      0   97212
# 6            0.688977                    155                      1   97865
# 7            0.981679                    171                      0   50113
# 8            0.010381                    177                      1   88747
# 9            0.466782                    170                      0   43283
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# 5          0
# 6          0
# 7          0
# 8          1
# 9          0

# %%
df.tail(10)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 990          990   36  Female  Engineering     Accountant                 9
# 991          991   47    Male    Marketing        Manager                 2
# 992          992   46  Female           HR        Analyst                 8
# 993          993   47  Female           HR        Analyst                 5
# 994          994   47    Male    Marketing  HR Specialist                 2
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 990            0.558512                    182                      1   65638
# 991            0.889621                    243                      0   78726
# 992            0.955095                    176                      1   79044
# 993            0.932450                    193                      0   47301
# 994            0.992018                    186                      1   31507
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 990          1
# 991          1
# 992          1
# 993          0
# 994          0
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Department             1000 non-null   object
#  4   Job_Title              1000 non-null   object
#  5   Years_at_Company       1000 non-null   int64
#  6   Satisfaction_Level     1000 non-null   float64
#  7   Average_Monthly_Hours  1000 non-null   int64
#  8   Promotion_Last_5Years  1000 non-null   int64
#  9   Salary                 1000 non-null   int64
#  10  Attrition              1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours',
#        'Promotion_Last_5Years', 'Salary', 'Attrition'],
#       dtype='object')

# %%
df.isna
# Out:
# <bound method DataFrame.isna of      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0              0   27    Male    Marketing        Manager                 9
# 1              1   53  Female        Sales       Engineer                10
# 2              2   59  Female    Marketing        Analyst                 8
# 3              3   42  Female  Engineering        Manager                 1
# 4              4   44  Female        Sales       Engineer                10
# ..           ...  ...     ...          ...            ...               ...
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0              0.586251                    151                      0   60132
# 1              0.261161                    221                      1   79947
# 2              0.304382                    184                      0   46958
# 3              0.480779                    242                      0   40662
# 4              0.636244                    229                      1   74307
# ..                  ...                    ...                    ...     ...
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0
# ..         ...
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1
#
# [1000 rows x 11 columns]>

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.drop(columns="Employee_ID", inplace=True)

# %%
import matplotlib.pyplot as plt
df["Gender"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Gender count of employess")
plt.show()

# %%
df.groupby("Job_Title")["Salary"].mean().sort_values(ascending=False).plot(kind="line")
plt.title("Average salary by job title")
plt.xlabel("Job Title")
plt.ylabel("Average Salary")
plt.show()

# %%
df.groupby(["Department","Promotion_Last_5Years"])["Salary"].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
x=df[["Years_at_Company","Satisfaction_Level","Average_Monthly_Hours"]]
y=df["Salary"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x
# Out:
#      Years_at_Company  Satisfaction_Level  Average_Monthly_Hours
# 0                   9            0.586251                    151
# 1                  10            0.261161                    221
# 2                   8            0.304382                    184
# 3                   1            0.480779                    242
# 4                  10            0.636244                    229
# ..                ...                 ...                    ...
# 995                 3            0.377435                    239
# 996                 1            0.431152                    154
# 997                 3            0.647102                    206
# 998                 2            0.304813                    241
# 999                 1            0.940510                    159
#
# [1000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.21922963,  1.59321258, -0.73611199],
#        [-0.9292851 , -0.97940995,  1.13770504],
#        [-0.9292851 , -0.58366087,  0.66073344],
#        ...,
#        [-0.21922963, -0.01417045, -1.04273659],
#        [ 0.84585358, -0.13260609,  0.79701104],
#        [ 1.55590906, -1.55868985,  1.00142744]], shape=(800, 3))

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
x_test=scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[ 5.09391297e-01,  1.61532154e+00,  1.43421508e+00],
#        [-1.95648561e-01,  5.02264747e-01, -1.46945057e+00],
#        [ 1.56871368e-01,  1.44423197e-01, -1.11057055e+00],
#        [ 5.09391297e-01, -1.03729051e+00,  5.20702290e-01],
#        [-1.95648561e-01,  1.00973964e+00, -8.49566893e-01],
#        [ 1.56871368e-01, -5.77050417e-01, -1.40419966e+00],
#        [ 1.56871368e-01, -1.32872152e+00,  1.56471691e+00],
#        [ 8.61911226e-01, -3.79195409e-01,  5.53327746e-01],
#        [ 8.61911226e-01, -7.82646479e-01, -1.56732694e+00],
#        [-1.25320835e+00, -4.09426352e-01, -7.84315980e-01],
#        [ 1.21443116e+00,  1.43319870e+00,  2.27073179e-01],
#        [-1.95648561e-01,  1.79380638e+00, -1.30632329e+00],
#        [ 8.61911226e-01, -7.34173599e-01,  1.07533505e+00],
#        [ 5.09391297e-01,  1.00227913e+00,  1.53209145e+00],
#        [ 8.61911226e-01, -2.18260167e-01,  1.36896416e+00],
#        [-5.48168490e-01,  1.66481467e+00, -1.07794509e+00],
#        [ 8.61911226e-01, -1.52227020e+00,  1.04270960e+00],
#        [ 8.61911226e-01, -4.92841277e-01, -1.20844692e+00],
#        [-1.60572828e+00, -1.59149423e+00,  1.33633871e+00],
#        [-1.25320835e+00, -5.11407311e-01, -3.92810499e-01],
#        [ 1.56871368e-01,  2.79916092e-01, -1.04531963e+00],
#        [-1.60572828e+00,  9.75592556e-01, -2.29683215e-01],
#        [-1.25320835e+00, -1.42744673e+00,  7.16455030e-01],
#        [-1.60572828e+00,  6.77270210e-01,  2.92324092e-01],
#        [ 1.56871368e-01, -1.54435550e+00,  1.53209145e+00],
#        [-9.00688419e-01,  2.94316579e-01, -8.82192350e-01],
#        [-5.48168490e-01,  6.93563791e-01,  3.24949549e-01],
#        [ 1.56871368e-01, -1.39399562e+00, -1.56732694e+00],
#        [-5.48168490e-01,  8.14002165e-01, -2.94934129e-01],
#        [-1.25320835e+00,  1.37857758e+00,  1.07533505e+00],
#        [ 5.09391297e-01, -3.09672534e-02,  1.33633871e+00],
#        [-9.00688419e-01, -9.71866291e-01, -4.25435956e-01],
#        [-9.00688419e-01, -2.67095673e-01, -6.21188696e-01],
#        [ 8.61911226e-01, -1.57276797e+00, -1.11057055e+00],
#        [-9.00688419e-01, -1.17452018e+00,  6.18578660e-01],
#        [ 5.09391297e-01,  4.78572702e-01,  7.81705943e-01],
#        [ 1.56695108e+00, -8.86048277e-01, -9.14817807e-01],
#        [-5.48168490e-01,  2.17917803e-01,  8.79582314e-01],
#        [ 8.61911226e-01, -8.38041788e-01, -1.24107237e+00],
#        [ 1.56695108e+00,  9.91970978e-01,  3.57575006e-01],
#        [ 8.61911226e-01,  4.50223472e-01, -1.07794509e+00],
#        [-1.25320835e+00,  1.24591435e+00,  1.14058597e+00],
#        [-1.95648561e-01, -4.91072483e-01, -1.50207603e+00],
#        [-1.60572828e+00,  1.68284909e+00,  1.94447722e-01],
#        [-1.95648561e-01,  3.90584220e-01,  1.20583688e+00],
#        [ 1.56871368e-01, -1.51181524e+00,  1.30371325e+00],
#        [ 1.56695108e+00,  1.69219131e+00, -1.11057055e+00],
#        [ 5.09391297e-01, -1.23208741e+00,  1.07533505e+00],
#        [-9.00688419e-01, -4.36475370e-01,  1.62996782e+00],
#        [-9.00688419e-01,  1.44539304e+00,  4.55451376e-01],
#        [-1.25320835e+00, -3.32298392e-01,  1.33633871e+00],
#        [-5.48168490e-01, -5.25820830e-01,  9.77458684e-01],
#        [-1.95648561e-01,  6.22810111e-01,  8.46956857e-01],
#        [ 1.21443116e+00,  6.27497099e-01, -7.19065066e-01],
#        [-1.60572828e+00,  6.92179937e-01,  1.56471691e+00],
#        [ 1.56871368e-01,  7.32573811e-01, -9.80068720e-01],
#        [-1.25320835e+00,  1.41710415e+00,  1.43421508e+00],
#        [ 1.56871368e-01, -6.79020325e-01,  1.20583688e+00],
#        [ 1.56871368e-01,  8.58030069e-01, -1.43682511e+00]])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,mean_absolute_error

def results(predictions):
  print("Mean absolute error on model is {}:",format(mean_absolute_error(y_test,predictions)))
  print("Root Mean squared error on model is {}:",format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictionlr=lr.predict(x_test)

# %%
results(predictionlr)
# Out:
# Mean absolute error on model is {}: 17503.50810513767
# Root Mean squared error on model is {}: 20377.522679734273

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
svrmodel = SVR()
param_gridsvr={
    'C':[0.1,1,10],
    'epsilon':[ 0.1, 0.2, 0.5],
    'kernel':['linear','poly','rbf'],
    'degree':[ 2, 3, 4]
    }
gridsvr = GridSearchCV(svrmodel,param_gridsvr)
gridsvr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
gridsvr.best_params_
# Out:
# {'C': 10, 'degree': 2, 'epsilon': 0.1, 'kernel': 'linear'}

# %%
predicitionsvr=gridsvr.predict(x_test)

# %%
results(predicitionsvr)
# Out:
# Mean absolute error on model is {}: 17477.521000521876
# Root Mean squared error on model is {}: 20339.172475384043

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfmodel=RandomForestRegressor()
param_gridrf={
    "n_estimators":[2,3,4,5,6],
    "max_depth":[5,10,15]
}
gridrf=GridSearchCV(rfmodel,param_gridrf,cv=5)
gridrf.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
gridrf.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 5}

# %%
predictionofrfr=gridrf.predict(x_test)

# %%
results(predictionofrfr)
# Out:
# Mean absolute error on model is {}: 17766.30464936179
# Root Mean squared error on model is {}: 20742.283438719904

# %%
lr
# Out:
# LinearRegression()

# %%
joblib.dump(lr,"model.pkl")
# Out:
# ['model.pkl']

# %%
x.columns
# Out:
# Index(['Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours'], dtype='object')
